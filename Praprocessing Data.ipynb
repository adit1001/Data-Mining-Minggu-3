# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy.sparse
from sklearn.impute import SimpleImputer

# %%
dataset = pd.read_csv('salary_data.csv', sep=':')
dataset = pd.read_csv('salary_data.csv', sep=None, engine='python')
x = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

# %%
print(x)
# Out:
# [['Afghanistan' 'Asia' 'Monthly' 853.74 1001.15 252.53]
#  ['Aland Islands' 'Europe' 'Monthly' 3319.24 3858.35 972.52]
#  ['Albania' 'Europe' 'Monthly' 832.84 956.92 241.22]
#  ...
#  ['Yemen' 'Asia' 'Monthly' 120.98 133.36 33.62]
#  ['Zambia' 'Africa' 'Monthly' 0.26133504 0.28552394 0.072092424]
#  ['Zimbabwe' 'Africa' 'Monthly' 555.40204 602.37635 151.42305]]

# %%
print(y)
# Out:
# [4.4609700e+03 1.7124740e+04 4.2584900e+03 5.8241800e+03 6.9800000e+03
#  1.7653280e+04 1.4039600e+03 7.4444400e+03 5.7713000e+02 8.7803900e+03
#  5.6424600e+03 2.1774190e+04 1.7864690e+04 7.7647100e+03 1.7416000e+04
#  1.7553190e+04 1.0520600e+03 7.2500000e+03 4.3812700e+03 2.7378440e+04
#  8.7500000e+03 2.4492800e+03 7.1200000e+03 1.9942300e+03 5.5057800e+03
#  5.5675700e+03 3.8220300e+03 7.6095600e+03 1.2000000e+04 1.0588240e+04
#  7.9459500e+03 2.3848300e+03 1.8638900e+03 3.5924400e+03 3.3033100e+03
#  3.2720590e+04 8.7423300e+03 1.7406960e+04 3.1099400e+03 3.5127900e+03
#  9.2740900e+03 1.7945210e+04 5.1377900e+03 2.9004800e+03 5.3658600e+03
#  8.5395000e+02 1.2574850e+04 1.9613340e+04 2.4170500e+03 9.2987400e+03
#  4.0791700e+03 1.0211420e+04 1.1810680e+04 2.5637390e+04 6.9210000e+03
#  2.4703700e+03 1.5627200e+03 9.8600000e+03 6.0800000e+03 1.3292400e+03
#  7.6100000e+03 3.4322200e+03 2.0333300e+03 1.2896410e+04 7.1313000e+02
#  1.6855520e+04 9.3478300e+03 2.2093020e+04 1.9467230e+04 1.4799150e+04
#  5.7573100e+03 3.9800800e+03 1.0953400e+03 1.1231340e+04 1.7970400e+04
#  1.9466000e+03 1.8393900e+04 1.1522200e+04 1.7847030e+04 1.0370370e+04
#  1.9767440e+04 6.2300000e+03 5.9542000e+03 4.1869510e+04 3.6349900e+03
#  2.4492800e+03 3.7378700e+03 2.2505900e+03 5.0909100e+03 2.0817370e+04
#  5.9743600e+03 2.2464510e+04 1.7179200e+03 3.5044700e+03 4.7704700e+03
#  6.9882500e+03 1.5151160e+04 1.7230440e+04 2.7772400e+03 1.5391820e+04
#  2.8048780e+04 1.0141040e+04 3.6200800e+03 4.4243600e+03 1.1161290e+04
#  9.6335099e+02 1.2893000e+04 9.8004000e+02 9.9299000e+02 8.6578040e+03
#  3.8733300e+03 2.7768900e+03 1.6904400e+03 2.0858900e+03 2.5901640e+04
#  4.4283792e+03 2.3150110e+04 4.1263900e+03 3.5314400e+03 1.2917400e+03
#  6.7479000e+02 6.2553200e+03 5.5174600e+03 2.3687100e+03 2.1775900e+04
#  1.0100000e+04 1.4164900e+04 2.3282729e+02 4.6537800e+03 1.2262160e+04
#  8.4959800e+03 6.2700000e+03 6.5384600e+03 1.8921780e+04 2.5096200e+03
#  1.2579280e+04 4.4814800e+03 8.4338500e+03 2.8038800e+03 1.1565900e+03
#  4.1282500e+03 2.7031100e+03 2.2515860e+04 1.0893850e+04 3.4632400e+03
#  2.1656290e+04 2.2999500e+03 2.4331700e+03 1.9492700e+03 8.8700000e+03
#  2.1281570e+04 2.0572920e+04 1.2666100e+03 1.2200000e+04 7.6200000e+03
#  9.4600000e+03 5.0137000e+03 5.0097400e+03 8.8918200e+03 3.5115600e+03
#  7.7345500e+03 1.3002110e+04 7.4910000e+03 1.9230770e+04 9.7674400e+03
#  8.5501100e+03 4.7443400e+03 2.5326800e+03 5.5925900e+03 4.6666700e+03
#  1.5433400e+04 5.6296300e+03 3.9350200e+03 2.1458770e+04 1.3298172e+03
#  1.9893330e+04 2.5137400e+03 5.6544100e+03 6.2464400e+03 1.2382300e+03
#  2.7720590e+04 1.0295980e+04 9.3023300e+03 3.3610500e+03 2.0308500e+03
#  7.3661900e+03 1.2050740e+04 1.2391100e+03 3.3192000e+02 5.9280000e+02
#  1.0651800e+03 1.8389750e+04 5.0363930e+04 5.1200000e+01 1.7919250e+04
#  4.7532000e+03 2.2450800e+03 1.1846790e+04 3.7867200e+03 3.4595700e+03
#  6.4306800e+03 5.5205000e+03 1.2741200e+03 6.6571400e+03 6.6400000e+03
#  3.1065500e+03 2.7619800e+03 1.8637600e+04 3.2214630e+04 3.5250000e+04
#  3.8291200e+03 4.7735000e+02 3.6504800e+03 1.7165260e+04 3.1615200e+03
#  8.1800000e+03 1.2000000e+04 4.5038900e+03 5.9493000e+02 1.2711033e+00
#  2.6747720e+03]

# %%
x = pd.DataFrame(x)

# %%
x_11 = x.iloc[:, 0:11]

# %%
numeric_cols_11 = x_11.select_dtypes(include=[np.number]).columns
non_numeric_cols_11 = x_11.select_dtypes(exclude=[np.number]).columns

# %%
if len(numeric_cols_11) > 0:
    # Imputasi missing values untuk kolom numeric menggunakan strategi 'mean'
    imputer_numeric = SimpleImputer(strategy='mean')
    x_11[numeric_cols_11] = imputer_numeric.fit_transform(x_11[numeric_cols_11])

# %%
x.iloc[:, 0:11] = x_11

# %%
print(x)
# Out:
#                        0              1        2          3          4  \
# 0            Afghanistan           Asia  Monthly     853.74    1001.15
# 1          Aland Islands         Europe  Monthly    3319.24    3858.35
# 2                Albania         Europe  Monthly     832.84     956.92
# 3                Algeria         Africa  Monthly    1148.84    1308.81
# 4         American Samoa        Oceania  Monthly     1390.0     1570.0
# ..                   ...            ...      ...        ...        ...
# 216  Virgin Islands (US)  North America  Monthly     2380.0     2710.0
# 217       Western Sahara         Africa  Monthly     908.56    1011.67
# 218                Yemen           Asia  Monthly     120.98     133.36
# 219               Zambia         Africa  Monthly   0.261335   0.285524
# 220             Zimbabwe         Africa  Monthly  555.40204  602.37635
#
#              5
# 0       252.53
# 1       972.52
# 2       241.22
# 3       330.11
# 4        400.0
# ..         ...
# 216      680.0
# 217     254.86
# 218      33.62
# 219   0.072092
# 220  151.42305
#
# [221 rows x 6 columns]

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
ct = ColumnTransformer(transformers=[('encoser', OneHotEncoder(), [0])])
x = np.array(ct.fit_transform(x))

# %%
print(x)
# Out:
#   (0, 0)	1.0
#   (1, 1)	1.0
#   (2, 2)	1.0
#   (3, 3)	1.0
#   (4, 4)	1.0
#   (5, 5)	1.0
#   (6, 6)	1.0
#   (7, 7)	1.0
#   (8, 8)	1.0
#   (9, 9)	1.0
#   (10, 10)	1.0
#   (11, 11)	1.0
#   (12, 12)	1.0
#   (13, 13)	1.0
#   (14, 14)	1.0
#   (15, 15)	1.0
#   (16, 16)	1.0
#   (17, 17)	1.0
#   (18, 18)	1.0
#   (19, 19)	1.0
#   (20, 20)	1.0
#   (21, 21)	1.0
#   (22, 22)	1.0
#   (23, 23)	1.0
#   (24, 24)	1.0
#   :	:
#   (196, 196)	1.0
#   (197, 197)	1.0
#   (198, 198)	1.0
#   (199, 199)	1.0
#   (200, 200)	1.0
#   (201, 201)	1.0
#   (202, 202)	1.0
#   (203, 203)	1.0
#   (204, 204)	1.0
#   (205, 205)	1.0
#   (206, 206)	1.0
#   (207, 207)	1.0
#   (208, 208)	1.0
#   (209, 209)	1.0
#   (210, 210)	1.0
#   (211, 211)	1.0
#   (212, 212)	1.0
#   (213, 213)	1.0
#   (214, 214)	1.0
#   (215, 215)	1.0
#   (216, 216)	1.0
#   (217, 217)	1.0
#   (218, 218)	1.0
#   (219, 219)	1.0
#   (220, 220)	1.0

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y = le.fit_transform(y)

# %%
print(y)
# Out:
# [ 85 177  81 107 120 183  25 125   5 140 104 203 185 131 181 182  14 123
#   82 211 139  43 122  32  98 101  73 127 162 155 132  40  29  67  58 215
#  138 180  56  65 143 187  96  54  97  10 166 195  41 144  78 152 160 209
#  119  44  26 149 110  23 128  60  34 169   9 176 146 205 194 172 106  77
#   16 158 188  30 190 159 184 154 196 111 108 217  69  43  71  37  95 199
#  109 206  28  63  92 121 173 179  52 174 213 151  68  83 157  11 168  12
#   13 137  75  51  27  35 210  84 208  79  66  22   8 113  99  39 204 150
#  171   2  88 165 135 114 116 192  45 167  86 134  53  17  80  49 207 156
#   62 202  38  42  31 141 200 198  20 164 129 147  94  93 142  64 130 170
#  126 193 148 136  90  47 102  89 175 103  76 201  24 197  46 105 112  18
#  212 153 145  59  33 124 163  19   3   6  15 189 218   1 186  91  36 161
#   72  61 115 100  21 118 117  55  50 191 214 216  74   4  70 178  57 133
#  162  87   7   0  48]
